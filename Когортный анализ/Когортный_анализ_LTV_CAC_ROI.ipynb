# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изменение типа данных</a></span></li><li><span><a href="#Проверка-данных-на-дубликаты" data-toc-modified-id="Проверка-данных-на-дубликаты-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка данных на дубликаты</a></span></li><li><span><a href="#Выводы-по-обработке-данных" data-toc-modified-id="Выводы-по-обработке-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Выводы по обработке данных</a></span></li></ul></li><li><span><a href="#Определение-функций-для-расчета-LTD,-ROI,-удержания-и-конверсии" data-toc-modified-id="Определение-функций-для-расчета-LTD,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Определение функций для расчета LTD, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-получения-пользовательских-профилей" data-toc-modified-id="Функция-получения-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция получения пользовательских профилей</a></span></li><li><span><a href="#Функция-расчета-LTV-и-ROI" data-toc-modified-id="Функция-расчета-LTV-и-ROI-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция расчета LTV и ROI</a></span></li><li><span><a href="#Визуализация-LTV,-ROI-и-динамики-трат-на-рекламу" data-toc-modified-id="Визуализация-LTV,-ROI-и-динамики-трат-на-рекламу-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Визуализация LTV, ROI и динамики трат на рекламу</a></span></li><li><span><a href="#Функция-сглаживания" data-toc-modified-id="Функция-сглаживания-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция сглаживания</a></span></li><li><span><a href="#Функция-расчета-коэффициента-удержания" data-toc-modified-id="Функция-расчета-коэффициента-удержания-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция расчета коэффициента удержания</a></span></li><li><span><a href="#Визуализация-коэффициента-ударжания" data-toc-modified-id="Визуализация-коэффициента-ударжания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Визуализация коэффициента ударжания</a></span></li><li><span><a href="#Функция-расчета-конверсии" data-toc-modified-id="Функция-расчета-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция расчета конверсии</a></span></li><li><span><a href="#Визуализация-конверсии-пользователей" data-toc-modified-id="Визуализация-конверсии-пользователей-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Визуализация конверсии пользователей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей-и-опраделение-минимальной-и-максимальной-даты-привлечения" data-toc-modified-id="Создание-пользовательских-профилей-и-опраделение-минимальной-и-максимальной-даты-привлечения-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание пользовательских профилей и опраделение минимальной и максимальной даты привлечения</a></span></li><li><span><a href="#Из-какой-страны-приходит-наибольшее-кол-во-пользователей-и-где-наиболее-платежеспособные" data-toc-modified-id="Из-какой-страны-приходит-наибольшее-кол-во-пользователей-и-где-наиболее-платежеспособные-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Из какой страны приходит наибольшее кол-во пользователей и где наиболее платежеспособные</a></span></li><li><span><a href="#Устройства,-которым-отдают-предпочтение-пользователи" data-toc-modified-id="Устройства,-которым-отдают-предпочтение-пользователи-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Устройства, которым отдают предпочтение пользователи</a></span></li><li><span><a href="#Определение-наиболее-популярных-источников-привлечения-пользователей" data-toc-modified-id="Определение-наиболее-популярных-источников-привлечения-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Определение наиболее популярных источников привлечения пользователей</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Распределение-трат-на-маркетинг-в-зависимости-от-источника" data-toc-modified-id="Распределение-трат-на-маркетинг-в-зависимости-от-источника-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределение трат на маркетинг в зависимости от источника</a></span></li><li><span><a href="#Стоимость-привлечения-одного-пользователя-в-зависимости-от-источника" data-toc-modified-id="Стоимость-привлечения-одного-пользователя-в-зависимости-от-источника-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Стоимость привлечения одного пользователя в зависимости от источника</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-пользователей" data-toc-modified-id="Средняя-стоимость-привлечения-пользователей-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Средняя стоимость привлечения пользователей</a></span></li><li><span><a href="#Выводы-по-исследованию-маркетинга" data-toc-modified-id="Выводы-по-исследованию-маркетинга-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выводы по исследованию маркетинга</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Графики-LTV-и-ROI,-и-их-динамика" data-toc-modified-id="Графики-LTV-и-ROI,-и-их-динамика-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Графики LTV и ROI, и их динамика</a></span></li><li><span><a href="#Окупаемость-рекламы-по-источникам-привлечения." data-toc-modified-id="Окупаемость-рекламы-по-источникам-привлечения.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость рекламы по источникам привлечения.</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Изучение-графиков-конверсии-и-удержания" data-toc-modified-id="Изучение-графиков-конверсии-и-удержания-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Изучение графиков конверсии и удержания</a></span><ul class="toc-item"><li><span><a href="#Разбивка-по-странам" data-toc-modified-id="Разбивка-по-странам-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Разбивка по странам</a></span></li><li><span><a href="#Распределение-по-источнику" data-toc-modified-id="Распределение-по-источнику-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Распределение по источнику</a></span></li><li><span><a href="#Распределение-по-устройству" data-toc-modified-id="Распределение-по-устройству-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Распределение по устройству</a></span></li></ul></li><li><span><a href="#Итоги-по-окупаемости" data-toc-modified-id="Итоги-по-окупаемости-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Итоги по окупаемости</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# В рамках проекта предстоит выяснить причины убытычности в приложении Procrastinate Pro+, не смотря на внушительные вложения в рекламу. Для выяснения причин стоит изучить следующие показатели:
#     1) Откуда приходят пользователи и какими устройствами они пользуются.
#     2) Сколько стоит привлечение пользователей из различных рекламных каналов.
#     3) Сколько денег приносит каждый клиент.
#     4) Когда расходы на привлечения клиента окупаются.
#     5) Какие факторы мешают привлечению клиентов.

# %% [markdown]
# ### Загрузка данных

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
try:
    visits = pd.read_csv('visits_info_short.csv')
    purchases = pd.read_csv('orders_info_short.csv')
    costs = pd.read_csv('costs_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    purchases = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %%
display(visits.head(5))
display(purchases.head(5))
display(costs.head(5))
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# ### Изменение типа данных

# %%
visits.info()
purchases.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# <b> В датасетах замечены следующие проблемы:
#     1) В столбцах Session Start, Session End, Event Dt, dt необходимо изменить тип на datetime.
#     2) Все имеющиеся столбцы надо привести к единому "змеиному" стилю.</b>

# %%
visits = visits.rename(columns= {'User Id':'user_id', 'Region':'region', 
                               'Device':'device', 'Channel':'channel', 'Session Start':'session_start', 
                               'Session End':'session_end'})

purchases.columns = [x.lower().replace(' ', '_') for x in purchases.columns.values]

costs.columns = costs.columns.str.lower()

# %% [markdown]
# Приводим колонки с датами к типу datetime

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
purchases['event_dt'] = pd.to_datetime(purchases['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ### Проверка данных на дубликаты

# %%
print('В таблице visits имеется дубликатов:',visits.duplicated().sum())
print('В таблице purchases имеется дубликатов:',purchases.duplicated().sum())
print('В таблице costs имеется дубликатов:',costs.duplicated().sum())
# Out:
# В таблице visits имеется дубликатов: 0
# В таблице purchases имеется дубликатов: 0
# В таблице costs имеется дубликатов: 0

# %% [markdown]
# ### Выводы по обработке данных

# %% [markdown]
# 1. Данные были приведены к единой стилистике.
# 2. Для дальнейшей работы в некоторых столбцах был изменен тип данных.
# 3. В данных не обнаружено пропусков.
# 4. Также данные не содержат дубликатов, поэтому их удаление также не потребовалось.

# %% [markdown]
# ## Определение функций для расчета LTD, ROI, удержания и конверсии

# %% [markdown]
# ### Функция получения пользовательских профилей

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):
    #print(sessions.info())
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )
    profiles['dt'] = profiles['first_ts'].dt.date
    #profiles['dt'] = pd.to_datetime(profiles['dt'])
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    #print(profiles.info())

    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    #print(new_users.info())
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция расчета LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
        roi = result.div(cac['cac'], axis=0)
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )
    if 'cohort' in dimensions:
        dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Визуализация LTV, ROI и динамики трат на рекламу

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(20, 10))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]
    cac_history = roi_history[['cac']]
    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция сглаживания

# %%
def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция расчета коэффициента удержания

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    # решаем какие столбцы оставим для группировки удержания, столбец признака платящего пользователя остается всегда
    dimensions = ['payer'] + dimensions
    
    # оттсекаем всех пользователей, которые не могли "дожить" до нужного горизонта 
    # (присоединились позже чем observation_date - horizon)
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # формируем массив сырых данных
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    # функция группировки по нужному набору измерений
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')     # строим "треугольную таблицу" 
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) # определяем размеры когорт
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   # присоединяем размеры когорт к треугольной таблице
        result = result.div(result['cohort_size'], axis = 0)                                                     # делим каждый из столбцов на размер когорты - расчитываем % удержания (retention rate)
        result = result[['cohort_size'] + list(range(horizon_days))]                                             # оставляем только наблюдения до нужного горизонта и столбец размеров когорт
        result['cohort_size'] = cohort_sizes                                                                     # пересприсваиваем столбец размеров когорт, ведь во время деления он превратился в 1
        return result
    
    # расчитываем удержание 
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    # рассчитываем удержание по всем параметрам + дата
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    # возвращаем и таблицы удержания и сырые данные (чтобы в случае чего можно было в них покопаться при отладке)
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Визуализация коэффициента ударжания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в четвёртой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция расчета конверсии

# %%
def get_conversion(
    profiles,
    purchases,  # заменили sessions
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # Получить пользовательские профили и данные о покупках
    # передаём их в качестве аргументов profiles и purchases

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # Найти дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # Добавить данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # Рассчитать лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):

        # Построить таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )

        # Посчитать сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)

        # Вычислить размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )

        # Объединить таблицы размеров когорт и конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)

        # Разделить каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)

        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Визуализация конверсии пользователей

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Создание пользовательских профилей и опраделение минимальной и максимальной даты привлечения

# %%
event = None # других событий нет
users = get_profiles(visits,purchases,event,costs)
users.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %%
min_date = users['first_ts'].min().date()
max_date = users['first_ts'].max().date()
print('Минимальная дата привлечения пользователя', min_date)
print('Максимальная дата привлечения пользователя', max_date)
# Out:
# Минимальная дата привлечения пользователя 2019-05-01
# Максимальная дата привлечения пользователя 2019-10-27

# %% [markdown]
# ### Из какой страны приходит наибольшее кол-во пользователей и где наиболее платежеспособные

# %%
users_for_country = users.pivot_table(index='region',columns='payer',values='user_id',
                                      aggfunc='count', margins=True, margins_name= 'total_users').reset_index()
users_for_country.columns = ['region','false','true','total_users']
#users_for_country=users_for_country.drop(labels=4,inplace=True)
users_for_country['share_of_users_from_total'] = round(users_for_country[
    'total_users']/users_for_country['total_users'].max()*100,2)
users_for_country['payer_true,%'] = round(users_for_country['true']/users_for_country['total_users']*100,2)

# %%
users_for_country
# Out:
#           region   false  true  total_users  share_of_users_from_total  \
# 0         France   16787   663        17450                      11.63
# 1        Germany   14365   616        14981                       9.99
# 2             UK   16875   700        17575                      11.72
# 3  United States   93100  6902       100002                      66.66
# 4    total_users  141127  8881       150008                     100.00
#
#    payer_true,%
# 0          3.80
# 1          4.11
# 2          3.98
# 3          6.90
# 4          5.92

# %% [markdown]
# <b> Наибольшее кол-во пользователей находится в United States 66.66% от общего числа. По проценту платящих пользователей в лидерах также находится United States 6,90%, так как пользователей больше, то возможно получить и бОльшую прибыль, откуда и появятся деньги на лишнюю рекламную компанию, которая увеличит долю покупателей. Поэтому наибольшая доля платящих клиентов в United States выглядит логично.</b>

# %% [markdown]
# ### Устройства, которым отдают предпочтение пользователи

# %%
users_for_device = users.pivot_table(index='device',columns='payer',values='user_id',
                                      aggfunc='count', margins=True, margins_name= 'total_users').reset_index()
users_for_device.columns = ['device','false','true','total_users']
#users_for_country=users_for_country.drop(labels=4,inplace=True)
users_for_device['share_of_users_from_total'] = round(users_for_device[
    'total_users']/users_for_device['total_users'].max()*100,2)
users_for_device['payer_true,%'] = round(users_for_device['true']/users_for_device['total_users']*100,2)

# %%
users_for_device
# Out:
#         device   false  true  total_users  share_of_users_from_total  \
# 0      Android   32982  2050        35032                      23.35
# 1          Mac   28130  1912        30042                      20.03
# 2           PC   28918  1537        30455                      20.30
# 3       iPhone   51097  3382        54479                      36.32
# 4  total_users  141127  8881       150008                     100.00
#
#    payer_true,%
# 0          5.85
# 1          6.36
# 2          5.05
# 3          6.21
# 4          5.92

# %% [markdown]
# <b> Большая часть пользователей использует iPhone - 36.32%, остальные устройства менее популярны и их доля = 20-24%. С iPhone производится 6,21% платежей от их пользователей, но наибольшей долей обладают пользователи Mac 6,36%.</b>

# %% [markdown]
# ### Определение наиболее популярных источников привлечения пользователей

# %%
users_for_channel = users.pivot_table(index='channel',columns='payer',values='user_id',
                                      aggfunc='count', margins=True, margins_name= 'total_users').reset_index()
users_for_channel.columns = ['channel','false','true','total_users']
users_for_channel['share_of_users_from_total'] = round(users_for_channel[
    'total_users']/users_for_channel['total_users'].max()*100,2)
users_for_channel['payer_true,%'] = round(users_for_channel['true']/users_for_channel['total_users']*100,2)

# %%
users_for_channel
# Out:
#                channel   false  true  total_users  share_of_users_from_total  \
# 0           AdNonSense    3440   440         3880                       2.59
# 1             FaceBoom   25587  3557        29144                      19.43
# 2              LeapBob    8291   262         8553                       5.70
# 3         MediaTornado    4208   156         4364                       2.91
# 4   OppleCreativeMedia    8372   233         8605                       5.74
# 5       RocketSuperAds    4096   352         4448                       2.97
# 6               TipTop   17683  1878        19561                      13.04
# 7       WahooNetBanner    8100   453         8553                       5.70
# 8              YRabbit    4147   165         4312                       2.87
# 9       lambdaMediaAds    1924   225         2149                       1.43
# 10             organic   55279  1160        56439                      37.62
# ...

# %% [markdown]
# <b> Среди специальных рекламных источников наиболее популярны FaceBoom и TipTop их доля 31,15% и 20,91% соответственно. Эффективность привлечения пользователей тем или иным каналом выражается значением payer_true,%, исходя из него можно отметить качество привлекаемых клиентов в источниках AdNonSense и lambdaMediaAds, которые несмотря на свою малую аудиторию имеют наиболее высокую долю платящих клиентов: 11,34% и 10,47% соответственно. Лидером по качеству привлекаемых клиентов является канал FaceBoom -12.20%</b>

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Распределение трат на маркетинг в зависимости от источника

# %%
costs['month'] = costs['dt'].astype('datetime64[M]')
costs['week'] = costs['dt'].astype('datetime64[W]')
costs.head()
# Out:
#            dt   channel  costs      month       week
# 0  2019-05-01  FaceBoom  113.3 2019-05-01 2019-04-25
# 1  2019-05-02  FaceBoom   78.1 2019-05-01 2019-05-02
# 2  2019-05-03  FaceBoom   85.8 2019-05-01 2019-05-02
# 3  2019-05-04  FaceBoom  136.4 2019-05-01 2019-05-02
# 4  2019-05-05  FaceBoom  122.1 2019-05-01 2019-05-02

# %%
channel_costs = costs.pivot_table(index='channel',values='costs',aggfunc='sum', margins=True, margins_name= 'All_channel')
display(channel_costs.sort_values(by='costs',ascending=False))
# Out:
#                         costs
# channel
# All_channel         105497.30
# TipTop               54751.30
# FaceBoom             32445.60
# WahooNetBanner        5151.00
# AdNonSense            3911.25
# OppleCreativeMedia    2151.25
# RocketSuperAds        1833.00
# LeapBob               1797.60
# lambdaMediaAds        1557.60
# MediaTornado           954.48
# YRabbit                944.22

# %%
distribution_expences = costs.pivot_table(index='month',columns='channel',values='costs',aggfunc='sum')
display(distribution_expences)

distribution_expences.plot(grid=True,title='Распределение трат на рекламу по источникам',figsize=(16,8));
plt.ylabel('Стоимость рекламной компании, $')
plt.xlabel('Дата рекламной компании')
plt.show()
# Out:
# channel     AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# month
# 2019-05-01     1169.70    3524.4   140.28        238.56              169.75
# 2019-06-01      538.65    5501.1   314.58        138.00              370.00
# 2019-07-01      504.00    5294.3   313.53        138.48              366.50
# 2019-08-01      579.60    6274.4   369.81        154.56              439.25
# 2019-09-01      581.70    6114.9   343.98        144.72              427.75
# 2019-10-01      537.60    5736.5   315.42        140.16              378.00
#
# channel     RocketSuperAds   TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# month
# 2019-05-01         577.980   2981.0           418.8   299.70           458.4
# 2019-06-01         325.715   6675.6           921.0   106.20           199.2
# 2019-07-01         252.070   8410.2           851.4    97.38           219.2
# 2019-08-01         253.110  11202.0          1040.4   124.74           220.0
# ...

# %% [markdown]
# Увеличим график, для определения САС источников, отличных от наиболее затратных TipTop и FaceBoom

# %%
distribution_expences.plot(grid=True,ylim=[0,1500],figsize=(16,8));
plt.ylabel('Стоимость рекламной компании, $')
plt.xlabel('Дата рекламной компании')
plt.show()

# %% [markdown]
# <b> За весь период на рекламу было затрачено 105497.30. Есть два источника, выделяющиеся объемом рекламных затрат, это FaceBoom и TipTop на них было потрачено 32445.60 и 54751.30 соответственно, что больше остальных затрат более чем в 6 раз.</b>

# %% [markdown]
# ### Стоимость привлечения одного пользователя в зависимости от источника

# %% [markdown]
# В таблице users, где содержатся профили пользоватей уже были добавлены расходы на рекламу acquisition_cost на уникального пользователя user_id. Будем использовать эту таблицу для расчета динамики стоимости привлечения клиента, также исключим из нее пользователей из channel==organic, так как затраты на таких пользователей по умолчанию равны 0, но на значений расчет средних значений пользователи organic могут повлиять.

# %%
users = users.query('channel != "organic"')
users.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(16, 8))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <b> Цена привлечения клиент в источниках втечении наблюдаемого периода сильно не меняется и его цена 0,2 - 1,2$ в зависимости от канала привлечения. Исключение составляет канал TipTop в течении периода у него было 4 скачка на удорожание рекламы, поэтому здесь можно подумать о снижении кол-ва привлекаемых клиентов или увеличении стоимости самой рекламной компании, которая впоследствии себя неоправдала.</b>

# %% [markdown]
# ### Средняя стоимость привлечения пользователей

# %%
print('Средняя стоимость привлечения пользователей: ', round(users['acquisition_cost'].sum()/users['user_id'].count(),2))
# Out:
# Средняя стоимость привлечения пользователей:  1.13

# %%
mean_cost = (
        users.groupby('channel')
        .agg(
            {
                'user_id': 'count',
                'acquisition_cost': 'mean',
            }
        )
    )
  
mean_cost.loc['mean'] = mean_cost.mean()
mean_cost['acquisition_cost'] = round(mean_cost['acquisition_cost'],2)   
mean_cost
# Out:
#                     user_id  acquisition_cost
# channel
# AdNonSense           3880.0              1.01
# FaceBoom            29144.0              1.11
# LeapBob              8553.0              0.21
# MediaTornado         4364.0              0.22
# OppleCreativeMedia   8605.0              0.25
# RocketSuperAds       4448.0              0.41
# TipTop              19561.0              2.80
# WahooNetBanner       8553.0              0.60
# YRabbit              4312.0              0.22
# lambdaMediaAds       2149.0              0.72
# mean                 9356.9              0.76

# %% [markdown]
# <b> Средняя стоимость привлечения пользователей равна 1,13.
#     Если сравнивать средние затраты на привлечение пользователей по источнику, то значение варьируется от  0,21-2,80. Их среднее получится 0,76, в сравнениии со средней стоимостью привлечения без разбивки по источникам это число будет меньше, следовательно, значительная часть пользователей пришла из канала TipTop, имеющего наибольшую стоимость за привлечение клиента 2,80. </b>

# %% [markdown]
# ### Выводы по исследованию маркетинга

# %% [markdown]
# 1. Самые большие траты на рекламу приходятся на источники FaceBoom и TipTop.
# 2. Затраты на привлечение по источнику TipTop заметно выросли в период наблюдения, отсюда такая средняя цена. Следует проследить динамику прироста клиентов по месяцам.
# 3. Средняя стоимость привлечения пользователей без группировки и с разрезом по источникам разнятся, большая часть пользователей приходит из дорогих источников привлечения.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# ### Графики LTV и ROI, и их динамика

# %% [markdown]
# По условию рекламная компания должна окупаться в течении 2 недель, поэтому установим границу наблюдений 14 дней.

# %%
observative_date = datetime(2019, 11, 1).date()
horizon = 14

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    users, purchases, observative_date, horizon)

# %%
plot_ltv_roi(
    ltv, ltv_history,
    roi, roi_history,
    horizon, window=7)

# %% [markdown]
# <b> Если рассматривать все данные без разбивки, то можно сказать, что к концу lifetime выручка ltv с клиента достигает ~0.9$. Динамика ltv пользователей на последний день lifetime можно назвать "цикличным" примерно 1 раз в месяц происходит спад, значения графика колеблятся между ~0,8-1,0 без тенденций на увеличение или снижение, можно предположить, что удержание клиента стабильно и с имеющихся клиентов не получается извлечь бОльшую прибыль. График САС показывает увеличение стоимости клиента на всем его протяжении. Есть несколько резких скачков на увеличение САС в Мае, Июне, Августе и Сентябре. Как следствие, в общем за весь период рекламные компании себя не окупили в пеиод 14 дней. Это может быть связано с увеличением рекламных затрат, так как до конца июня, когда произошел очередной скачок САС, рекламные компании удавалось окупать. В дальнейшем параметр ROI варьируется около 0,8, здесь можно говорить об убыточности.</b>

# %% [markdown]
# ### Окупаемость рекламы по источникам привлечения.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    users, purchases, observative_date, horizon, dimensions = ['channel'])

# %%
plot_ltv_roi(
    ltv, ltv_history,
    roi, roi_history,
    horizon, window=7)

# %% [markdown]
# <b> С первого взгляда кажется, что наиболее прибыльными источниками являются lambdaMediaAds и TipTop, у них же наиболее высокая динамика ltv на 14 день, их периодические скачки выше остальных, что говорит о получении большей прибыли с клиента. У графика ROI лидеры несколько другие это: YRabbit, MediaTornado и lambdaMediaAds в порядке окупаемости. Такие данные можно обосновать средствами затраченными на их рекламу САС: у источника TipTop такой параметр сильно увеличился по ходу исследуемого периода, он же стал и наиболее затрратным каналом. У канала lambdaMediaAds ROI также один из самых высоких, поэтому по окупаемости он оказался на несколько позиций ниже. Динамика ROI на 14 день обосновывает окупаемость источников YRabbit и MediaTornado, по всплескам этих источников можно сказать, что наибольшая вероятность извлечения большей прибыли по истечению 14 дней можно ожидать от них. </b>

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    users, purchases, observative_date, horizon, dimensions = ['region'])

# %%
plot_ltv_roi(
    ltv, ltv_history,
    roi, roi_history,
    horizon, window=7)

# %% [markdown]
# <b> Наиболший показатель LTV показывают пользователи из United States, далее идут UK, Germany и France. Такой показатель логичен, так как в United States находится большее число клиентов и именно платящих в том числе. Однако, как раз в United States рекламные компании не окупаются показатель ROI ~0.8. Динимика ROI на 14 день у United States также ниже остальных и продолжает идти на спад. График САС обосновывает данное обстоятельство у United States стоимость привлечения клиента растет на протяжении всего наблюдаемого периода. Стоимость рекламных компаний у остальных компаний наоборот упала в июне, поэтому им удалось сохранить ROI>1, хотя динамика LTV в этот период демонстрирует падение спроса пользователей. </b>

# %% [markdown]
# ### Изучение графиков конверсии и удержания

# %% [markdown]
# #### Разбивка по странам

# %%
retention_raw, retention, retention_history = get_retention(
    users, visits, observative_date, horizon, dimensions=['region']
)

#retention

# %%
plot_retention(retention, retention_history, horizon, window=7)

# %% [markdown]
# <b> На графике удержания платящих пользователей выделяется линия United State, их пользватели задерживаются в приложении меньше остальных. В других случаях между странами идет конкуренция и каждая имеет наиболее высокий показатель в определенный период времени, также в некоторых случаях можно увидеть прирост удержания, что свидетельствует о том что в определенных странах, в некоторый период лайфтайма произошло увеличение кол-ва пользователей, что привело к росту удержания. Удержание неплатящих пользователей одинаково для всех стран и их показатель ниже чем в аналогичном лайфтайме платящего пользователя.</b>

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    users,
    purchases,  # заменили sessions
    observative_date, horizon, dimensions=['region'])

#conversion

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(conversion.drop(columns=['cohort_size']), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии по странам')
plt.show() 

plot_conversion(conversion, conversion_history, horizon)

# %% [markdown]
# <b> Лучше всего конвертируются пользователи из United States, 7,19 % совершают покупки в перый день, а к концу 2 недели доля, совершивших покупки достигает 9,61%
#     Худшая конверция наблюдается у пользователей из Germany, в первый день их доля 3.23%, а концу периода горизонта наблюдения 5.05% по этомупоказателю они передвинулись на 2 место, что можно обосновать хорошими показателяями по удержанию.</b>

# %% [markdown]
# #### Распределение по источнику

# %%
retention_raw, retention, retention_history = get_retention(
    users, visits, observative_date, horizon, dimensions=['channel']
)

#retention

# %%
plot_retention(retention, retention_history, horizon, window=7)

# %% [markdown]
# <b> Среди платящих пользователей с худшей стороны выделяются удержанием источники AdNonSense и FaceBoom. Их удержание уже в 1 день почти в 2 раза меньше, чем у остальных источников. Источники с наиболее высоким удержением можно назвать RocketSuperAds и WahooNetBanner. Среди неплатящих пользователей показатели удержания примерно равны и на первый день они уже меньше 0,2. </b>

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    users,
    purchases,  # заменили sessions
    observative_date, horizon, dimensions=['channel'])

#conversion

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(conversion.drop(columns=['cohort_size']), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии по источникам')
plt.show() 

plot_conversion(conversion, conversion_history, horizon)

# %% [markdown]
# <b> Наиболее высоким показателем конверсии обладает источник FaceBoom - 10,21%, в конце лайфтайма доля людей совершивших покупки в период лайфтайма достигает 11,94%.
# Самая маленькая конверсия находится у пользователей OppleCreativeMedia-1.73% и к концу своего лайфтайма вырастает только до 2.63%.</b>

# %% [markdown]
# #### Распределение по устройству

# %%
retention_raw, retention, retention_history = get_retention(
    users, visits, observative_date, horizon, dimensions=['device']
)

#retention

# %%
plot_retention(retention, retention_history, horizon, window=7)

# %% [markdown]
# <b> На графике платящих пользователей наибольшим удержанием обладают пользователи РС. У пользователей Android наблюдается восстановление удержания, что может быть связано с увеличением кол-ва клиентов. Графики удержания для неплатящих клиентов совпадают и в 1 день их показатели меньше 0,2.</b>

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    users,
    purchases,  # заменили sessions
    observative_date, horizon, dimensions=['device'])

#conversion

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(conversion.drop(columns=['cohort_size']), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии по устройствам')
plt.show() 

plot_conversion(conversion, conversion_history, horizon)

# %% [markdown]
# <b> Наиболее высокая конверсия наблюдается у пользователей Мас 6,43%, к концу периода лайфтайм доля пользователей совершивших покупку достигает 8.71%.
# Самая маленькая конверсия наблюдается у пользователей РС 4.66% и к концу периода лайфтайм их доля 6.54%.</b>

# %% [markdown]
# ### Итоги по окупаемости

# %% [markdown]
# 1. По истечению 14 дней рекламные вложения в среднем не окупаются. До июля реклама себя оправдывала, но после коэффициент ROI стал меньше 1 и стабильно уменьшался.
# 2. Графики САС с разбивкой по странам== United States и по источникам==TipTop похожи, поэтому можно предположить, что в данной стране TipTop не пользуется популярностью и следует обратить внимание на другие источники.

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Приложение Procratinate Pro+ не окупает свои расходы на рекламу по истечению 2 недель. При анализе прибыли от данного приложения по странам было выявлено, что оно не окупается только в Unated States. График затрат САС для Unated States очень напоминает подобный график для источника TipTop, откуда можно сделать вывод, что в этой стране очень активно используется источник привлечения клиентов TipTop. Сами графики затрат САС демонстрируют скачкообразное увеличение стоимости привлечения клиента в стране, как итог по графику ROI полученная прибыль не окупила затраты.
# 2. Причина неэффективности в привлечении видна по низким показателям удержания пользователей. Несмотря на самый высокий показатель LTV и конверсии, картина с удержанием прямопротивоположная.
# 3. В виду вышеуказанных выводов считаю рынок в United States довольно перспективным, но там следует попробовать другие источники привлечения, так как на TipTop затраты достаточно велики. Наиболее перспективными я бы назвал RocketSuperAds, MediaTornado и YRabbit, а FaceBoom судя по графикам не окупается поэтому пока его оставим в стороне.
